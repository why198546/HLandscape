# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://mp.weixin.qq.com/s/bMn55dAh5JUYWmnPlruVwA"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table')  # find the table in the webpage

data = []
for row in table.find_all('tr'):  # find each row in the table
    cols = row.find_all('td')  # find each column in the row
    cols = [ele.text.strip() for ele in cols]
    data.append(cols)

df = pd.DataFrame(data)  # convert the data to a pandas DataFrame

print(df)
# Out:
#          0                                    1          2                3
# 0       北京                                 None       None             None
# 1     中标时间                                 项目名称  中标金额(人民币)             中标公司
# 2    6月30日                         延庆区道路绿化工程二标段      838万元    北京绿佳杰园林工程有限公司
# 3    6月29日                          党校西绿地绿化建设工程      646万元   北京京润园林绿化工程有限公司
# 4    6月29日                德胜街道2023年绿地养护及树木抢排险项目      146万元   北京西城园林绿化有限责任公司
# ..     ...                                  ...        ...              ...
# 114  6月15日         天津市机电工艺技师学院2023-2025年度绿化服务项目      410万元  天津荣隆达园林绿化工程有限公司
# 115  6月14日                     2023年和平区绿化养护服务项目      545万元      天津市绿化工程有限公司
# 116   6月9日                  金桥街道军粮城农业园一标段绿化养护项目      220万元      天津市久益集团有限公司
# 117   6月6日  北闸口镇2018年度造林绿化工程2023-2024年度养护管理服务项目       99万元       天津春浓林业有限公司
# 118   6月1日       天津市肿瘤医院空港医院室外绿化养护和楼内花卉租摆服务采购项目      197万元    天津花之富花卉销售有限公司
#
# [119 rows x 4 columns]

# %%
# Initialize a city variable with a default value
current_city = '未知'

# Define a function to determine the city
def determine_city(row):
    global current_city
    if pd.notnull(row[0]) and pd.isnull(row[1]) and pd.isnull(row[2]) and pd.isnull(row[3]):
        current_city = row[0]
    return current_city

# Apply the function to each row again
df['城市'] = df.apply(determine_city, axis=1)

# Remove the rows with city names
df = df.dropna(subset=[1, 2, 3], how='all')

# Rename the columns
df.columns = ['中标时间', '项目名称', '中标金额(人民币)', '中标公司', '城市']

df.head(10)
# Out:
#      中标时间                                               项目名称  中标金额(人民币)  \
# 1    中标时间                                               项目名称  中标金额(人民币)
# 2   6月30日                                       延庆区道路绿化工程二标段      838万元
# 3   6月29日                                        党校西绿地绿化建设工程      646万元
# 4   6月29日                              德胜街道2023年绿地养护及树木抢排险项目      146万元
# 5   6月28日                  北京城市副中心住房项目（0701街区）D#地块第一标段景观园林工程     2347万元
# 6   6月28日  南区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：黄村公园、街心公园      477万元
# 7   6月28日  北区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：滨河运动公园...      255万元
# 8   6月28日                                   2023年丰台区古树复壮修复项目      120万元
# 9   6月27日                                      海淀区古树医院公园建设项目      289万元
# 10  6月27日         密云区太师屯镇2022年国家储备林建设项目密云区太师屯镇2022年国家储备林建设项目      176万元
#
#               中标公司  城市
# 1             中标公司  北京
# 2    北京绿佳杰园林工程有限公司  北京
# 3   北京京润园林绿化工程有限公司  北京
# 4   北京西城园林绿化有限责任公司  北京
# 5    北京市园林绿化集团有限公司  北京
# 6   北京日出枫林园林工程有限公司  北京
# 7    北京华景域园林工程有限公司  北京
# 8   北京鑫欣明睿园林工程有限公司  北京
# 9   北京如景生态园林绿化有限公司  北京
# 10      北京龙泉湖畔集体林场  北京

# %%
df = df.iloc[1:]

# %%
df
# Out:
#       中标时间                                               项目名称 中标金额(人民币)  \
# 2    6月30日                                       延庆区道路绿化工程二标段     838万元
# 3    6月29日                                        党校西绿地绿化建设工程     646万元
# 4    6月29日                              德胜街道2023年绿地养护及树木抢排险项目     146万元
# 5    6月28日                  北京城市副中心住房项目（0701街区）D#地块第一标段景观园林工程    2347万元
# 6    6月28日  南区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：黄村公园、街心公园     477万元
# ..     ...                                                ...       ...
# 114  6月15日                       天津市机电工艺技师学院2023-2025年度绿化服务项目     410万元
# 115  6月14日                                   2023年和平区绿化养护服务项目     545万元
# 116   6月9日                                金桥街道军粮城农业园一标段绿化养护项目     220万元
# 117   6月6日                北闸口镇2018年度造林绿化工程2023-2024年度养护管理服务项目      99万元
# 118   6月1日                     天津市肿瘤医院空港医院室外绿化养护和楼内花卉租摆服务采购项目     197万元
#
#                 中标公司  城市
# 2      北京绿佳杰园林工程有限公司  北京
# 3     北京京润园林绿化工程有限公司  北京
# 4     北京西城园林绿化有限责任公司  北京
# 5      北京市园林绿化集团有限公司  北京
# 6     北京日出枫林园林工程有限公司  北京
# ..               ...  ..
# 114  天津荣隆达园林绿化工程有限公司  天津
# 115      天津市绿化工程有限公司  天津
# 116      天津市久益集团有限公司  天津
# 117       天津春浓林业有限公司  天津
# 118    天津花之富花卉销售有限公司  天津
#
# [115 rows x 5 columns]

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client['中标公示']
collection = db['projects']

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), '中标公示')

# %%
data = df.to_dict(orient='records')  # 'df' is your DataFrame

# %%
data
# Out:
# [{'中标时间': '中标时间',
#   '项目名称': '项目名称',
#   '中标金额(人民币)': '中标金额(人民币)',
#   '中标公司': '中标公司',
#   '城市': '北京'},
#  {'中标时间': '6月30日',
#   '项目名称': '延庆区道路绿化工程二标段',
#   '中标金额(人民币)': '838万元',
#   '中标公司': '北京绿佳杰园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月29日',
#   '项目名称': '党校西绿地绿化建设工程',
#   '中标金额(人民币)': '646万元',
#   '中标公司': '北京京润园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月29日',
#   '项目名称': '德胜街道2023年绿地养护及树木抢排险项目',
#   '中标金额(人民币)': '146万元',
#   '中标公司': '北京西城园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月28日',
#   '项目名称': '北京城市副中心住房项目（0701街区）D#地块第一标段景观园林工程',
#   '中标金额(人民币)': '2347万元',
#   '中标公司': '北京市园林绿化集团有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月28日',
#   '项目名称': '南区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：黄村公园、街心公园',
#   '中标金额(人民币)': '477万元',
#   '中标公司': '北京日出枫林园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月28日',
#   '项目名称': '北区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：滨河运动公园、翡翠公园、地铁文化公园',
#   '中标金额(人民币)': '255万元',
#   '中标公司': '北京华景域园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月28日',
#   '项目名称': '2023年丰台区古树复壮修复项目',
#   '中标金额(人民币)': '120万元',
#   '中标公司': '北京鑫欣明睿园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月27日',
#   '项目名称': '海淀区古树医院公园建设项目',
#   '中标金额(人民币)': '289万元',
#   '中标公司': '北京如景生态园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月27日',
#   '项目名称': '密云区太师屯镇2022年国家储备林建设项目密云区太师屯镇2022年国家储备林建设项目',
#   '中标金额(人民币)': '176万元',
#   '中标公司': '北京龙泉湖畔集体林场',
#   '城市': '北京'},
#  {'中标时间': '6月26日',
#   '项目名称': '北京城市副中心住房项目（0701街区）E#地块第二标段景观园林工程',
#   '中标金额(人民币)': '1882万元',
#   '中标公司': '北京政平建设投资集团有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月26日',
#   '项目名称': '北京城市副中心住房项目（0701街区）D#地块第二标段景观园林工程',
#   '中标金额(人民币)': '1925万元',
#   '中标公司': '北京安海之弋园林古建工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月26日',
#   '项目名称': '北京城市副中心住房项目（0701街区）E#地块第一标段景观园林工程',
#   '中标金额(人民币)': '1705万元',
#   '中标公司': '北京京润园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '北京市延庆区南菜园1-5巷棚户区改造项目YQ00-0007-0002地块R2二类居住用地项目（1#住宅楼等12项）（山澜阙府）园林绿化工程（施工）',
#   '中标金额(人民币)': '487万元',
#   '中标公司': '北京市园林设计工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '昌平区2023年马池口镇平原重点区域造林绿化工程（一标段）',
#   '中标金额(人民币)': '478万元',
#   '中标公司': '北京绿迪源园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '昌平区2023年马池口镇平原重点区域造林绿化工程（二标段）',
#   '中标金额(人民币)': '458万元',
#   '中标公司': '北京如景生态园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '2023年公园附属设施养护及维修专项项目二标段',
#   '中标金额(人民币)': '363万元',
#   '中标公司': '北京金都园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '2023年公园附属设施养护及维修专项项目一标段',
#   '中标金额(人民币)': '821万元',
#   '中标公司': '北京市新海园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '国家会议中心二期项目主体部分（会展中心等2项)园林景观工程（三标段）',
#   '中标金额(人民币)': '6555万元',
#   '中标公司': '上海园林(集团)有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月25日',
#   '项目名称': '昌平区2023年马池口镇平原重点区域造林绿化工程（三标段）',
#   '中标金额(人民币)': '968万元',
#   '中标公司': '北京翰林生态建设有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月21日',
#   '项目名称': '因电力安全大规格树木修剪项目',
#   '中标金额(人民币)': '149万元',
#   '中标公司': '北京福森园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月21日',
#   '项目名称': '格兰二期南侧绿地建设项目',
#   '中标金额(人民币)': '107万元',
#   '中标公司': '中昌泰（北京）建设集团有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月20日',
#   '项目名称': '疏整促-铁路沿线环境提升-京张铁路东升段沿线绿化景观工程园林绿化工程施工采购',
#   '中标金额(人民币)': '969万元',
#   '中标公司': '北京森源达生态环境股份有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月20日',
#   '项目名称': '北京市大兴区旧宫镇DX05-0102-6101、6102、YZ00-0801-0015、0016地块B4综合性商业金融服务业用地、U17邮政设施用地、R2二类居住用地（配建“公共租赁住房”）项目园林景观工程',
#   '中标金额(人民币)': '1399万元',
#   '中标公司': '北京艺苑风景园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月20日',
#   '项目名称': '昌平区2023年十三陵镇平原重点区域造林绿化工程',
#   '中标金额(人民币)': '3607万元',
#   '中标公司': '北京鼎通祥安园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月20日',
#   '项目名称': '2023年口袋公园建设设计项目',
#   '中标金额(人民币)': '180万元',
#   '中标公司': '北京市城美绿化设计工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月20日',
#   '项目名称': '石景山区2023年古树复壮保护服务项目',
#   '中标金额(人民币)': '154万元',
#   '中标公司': '北京华林森茂园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月20日',
#   '项目名称': '房山区河北镇檀木港石灰厂治理项目等3个项目绿化补充方案',
#   '中标金额(人民币)': '404万元',
#   '中标公司': '北京如景生态园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月19日',
#   '项目名称': '奥北森林公园建设工程（三期）设计',
#   '中标金额(人民币)': '300万元',
#   '中标公司': '北京北林地景园林规划设计院有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月19日',
#   '项目名称': '大兴区旧宫镇庑殿生态休闲公园（设计）',
#   '中标金额(人民币)': '311万元',
#   '中标公司': '北京市城美绿化设计工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月19日',
#   '项目名称': '延庆区2023年区级样板林示范区建设项目（国有林场管理中心部分）',
#   '中标金额(人民币)': '167万元',
#   '中标公司': '北京盛世润禾生态建设有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月15日',
#   '项目名称': '2023年全龄友好公园改造其他建筑工程采购项目',
#   '中标金额(人民币)': '1686万元',
#   '中标公司': '北京朝园弘园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月15日',
#   '项目名称': '河北镇兴河建材有限责任公司三福村项目和河北镇口儿煤矿等三个治理区（绿化工程）',
#   '中标金额(人民币)': '279万元',
#   '中标公司': '北京市绿欣园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月14日',
#   '项目名称': '北京舞蹈学院图书馆周边绿化工程',
#   '中标金额(人民币)': '172万元',
#   '中标公司': '北京丁土园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月14日',
#   '项目名称': '2023年丰台区林荫路绿化项目',
#   '中标金额(人民币)': '495万元',
#   '中标公司': '北京润禾建设工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月13日',
#   '项目名称': '平谷区2023年废弃矿山绿化提升项目',
#   '中标金额(人民币)': '394万元',
#   '中标公司': '中矿复绿（北京）生态科技发展有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月13日',
#   '项目名称': '门头沟区2023年揭网见绿项目',
#   '中标金额(人民币)': '419万元',
#   '中标公司': '北京福森园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月13日',
#   '项目名称': '古树名木巡查及应急保护项目（01包）',
#   '中标金额(人民币)': '49万元',
#   '中标公司': '北京金都园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月13日',
#   '项目名称': '古树名木巡查及应急保护项目（02包）',
#   '中标金额(人民币)': '129万元',
#   '中标公司': '北京北亚园林有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月13日',
#   '项目名称': '村庄绿化美化长效管护',
#   '中标金额(人民币)': '766万元',
#   '中标公司': '北京天房绿茵园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月13日',
#   '项目名称': '昌崔路（官高路口—崔村小学）北侧机非隔离带垂直绿化项目',
#   '中标金额(人民币)': '157万元',
#   '中标公司': '北京润安园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月12日',
#   '项目名称': '小汤山镇葫芦河村绿化工程',
#   '中标金额(人民币)': '531万元',
#   '中标公司': '北京丰顺卉园园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月12日',
#   '项目名称': '2023年城市公园养护项目（新移交项目）第一包',
#   '中标金额(人民币)': '288万元',
#   '中标公司': '北京市新海园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月12日',
#   '项目名称': '2023年城市公园养护项目（新移交项目）第二包',
#   '中标金额(人民币)': '91万元',
#   '中标公司': '北京金都园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月12日',
#   '项目名称': '2023年平原生态林管护项目',
#   '中标金额(人民币)': '108万元',
#   '中标公司': '北京如景生态园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月12日',
#   '项目名称': '大兴区永定河管理所2012年平原造林林木资源养护工程（2023年7月1日至2026年6月30日）',
#   '中标金额(人民币)': '1679万元',
#   '中标公司': '北京顶峰国建园林工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月9日',
#   '项目名称': '昌平区2023年园林绿化局平原重点区域造林绿化工程',
#   '中标金额(人民币)': '1234万元',
#   '中标公司': '北京路桥海威园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月9日',
#   '项目名称': '北京市石景山区中关村科技园区石景山园北Ⅰ区1605-651地块B23研发设计用地项目-园林绿化工程（二次招标）',
#   '中标金额(人民币)': '1690万元',
#   '中标公司': '北京政平建设投资集团有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月9日',
#   '项目名称': '首都森林村庄建设试点示范应用及推广（施工）',
#   '中标金额(人民币)': '68万元',
#   '中标公司': '北京文茵风景园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月8日',
#   '项目名称': '国道230（K0+000-K13+114.628）道路工程-绿化工程-国道230（K0+000-K13+114.628）道路工程-绿化工程(施工)',
#   '中标金额(人民币)': '1230万元',
#   '中标公司': '北京路桥海威园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月8日',
#   '项目名称': '2023年度杨柳飞絮防治项目2包',
#   '中标金额(人民币)': '139万元',
#   '中标公司': '北京京生园园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月7日',
#   '项目名称': '石河营口袋公园建设工程',
#   '中标金额(人民币)': '290万元',
#   '中标公司': '北京森源达生态环境股份有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月6日',
#   '项目名称': '建设里公园公共空间改造提升项目（施工）',
#   '中标金额(人民币)': '671万元',
#   '中标公司': '北京金三环园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月6日',
#   '项目名称': '小营口袋公园建设工程',
#   '中标金额(人民币)': '249万元',
#   '中标公司': '北京丁土园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月5日',
#   '项目名称': '商务园T接北苑110千伏线路工程（道路及绿化）',
#   '中标金额(人民币)': '431万元',
#   '中标公司': '北京路桥海威园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月5日',
#   '项目名称': '通怀路（昌金路-京平高速公路）市政配套工程（景观提升工程）',
#   '中标金额(人民币)': '7305万元',
#   '中标公司': '北京金都园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月5日',
#   '项目名称': '顺义区后沙峪镇龙腾世纪文化广场改造提升工程（二次招标）',
#   '中标金额(人民币)': '2894万元',
#   '中标公司': '北京市园林绿化集团有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月5日',
#   '项目名称': '菜园街及枣林南里棚户区改造项目18#住宅、19#住宅楼、20#住宅楼、S7#楼、E-1#门卫、E2#门卫及地下车库园林景观工程',
#   '中标金额(人民币)': '410万元',
#   '中标公司': '北京世纪经典园林绿化有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月5日',
#   '项目名称': '2023年公园管理中心绿地养护项目（维修维护及苗木补植）绿海运动公园提升改造项目',
#   '中标金额(人民币)': '143万元',
#   '中标公司': '北京绿茵大地园林绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月2日',
#   '项目名称': '一亩园拆迁区域绿化建设工程（设计）',
#   '中标金额(人民币)': '352万元',
#   '中标公司': '北京市园林古建设计研究院有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月2日',
#   '项目名称': '丰台站周边交通及环境综合整治（第二批）-环境整治 （第四包）',
#   '中标金额(人民币)': '469万元',
#   '中标公司': '北京花乡花木集团有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月2日',
#   '项目名称': '北京市丰台区永定河管理所2023年丰台区平原造林养护项目（永定河丰台段）',
#   '中标金额(人民币)': '128万元',
#   '中标公司': '北京市京绿建设工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月1日',
#   '项目名称': '2023年北京城市副中心林荫路改造提升工程',
#   '中标金额(人民币)': '467万元',
#   '中标公司': '北京金都园林绿化有限责任公司',
#   '城市': '北京'},
#  {'中标时间': '6月1日',
#   '项目名称': '密云区溪翁庄镇环境治理项目',
#   '中标金额(人民币)': '78万元',
#   '中标公司': '北京溪盛绿化工程有限公司',
#   '城市': '北京'},
#  {'中标时间': '6月27日',
#   '项目名称': '中国邮政储蓄银行股份有限公司承德市分行新办公楼三楼阳台等景观绿化项目',
#   '中标金额(人民币)': '17万元',
#   '中标公司': '承德森韵园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月26日',
#   '项目名称': '唐山市环城水系提升改造综合治理工程PPP项目运营期园林绿化养护项目（2023-2024年度)中标结果',
#   '中标金额(人民币)': '178万元',
#   '中标公司': '唐山裕坤建设集团有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月26日',
#   '项目名称': '唐山南湖旅游景区绿化养护项目新四标段',
#   '中标金额(人民币)': '184万元',
#   '中标公司': '唐山市风景园林建设有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月26日',
#   '项目名称': '唐山南湖旅游景区绿化养护项目新五标段',
#   '中标金额(人民币)': '167万元',
#   '中标公司': '河北艺美盛璟园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月25日',
#   '项目名称': '张家口卷烟厂有限责任公司公司绿化项目',
#   '中标金额(人民币)': '168万元',
#   '中标公司': '张家口天泽绿化景观工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月25日',
#   '项目名称': '广平县新区二街道路两侧绿化工程',
#   '中标金额(人民币)': '461万元',
#   '中标公司': '河北力投建设工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月25日',
#   '项目名称': '广平县太极大道绿化提升银杏林建设工程 (203国道) -路西（分养护）',
#   '中标金额(人民币)': '552万元',
#   '中标公司': '河北源桐园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月25日',
#   '项目名称': '广平县太极大道绿化提升银杏林建设工程 (203国道) -路东',
#   '中标金额(人民币)': '359万元',
#   '中标公司': '邯郸市鑫梓源园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月25日',
#   '项目名称': '广平县新区一街道路两侧绿化工程',
#   '中标金额(人民币)': '772万元',
#   '中标公司': '卓恒建设集团有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月25日',
#   '项目名称': '玉水庭院·燕归来康养小镇项目45#地块景观及室外工程施工（一标段）',
#   '中标金额(人民币)': '1634万元',
#   '中标公司': '北京绿京华生态园林股份有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月20日',
#   '项目名称': '千亿级电子信息园和平路以北区域计三渠东侧绿化工程',
#   '中标金额(人民币)': '80万元',
#   '中标公司': '河北鹿鑫建筑工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月19日',
#   '项目名称': '北京交通大学海滨轨道交通综合研发实验基地项目-外网部分绿化硬化及苗木（2标段）',
#   '中标金额(人民币)': '473万元',
#   '中标公司': '沧州渤海新区大东泰市政园林建设工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月19日',
#   '项目名称': '山海关区文化体育活动中心景观绿化工程施工',
#   '中标金额(人民币)': '1160万元',
#   '中标公司': '秦皇岛兴龙建设工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月19日',
#   '项目名称': '迁西县2023年度荒山人工造林工程',
#   '中标金额(人民币)': '916万元',
#   '中标公司': '迁西县碧水田园农业发展有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月16日',
#   '项目名称': '振兴一路(邢州大道至龙岗大街)道路绿化工程EPC总承包',
#   '中标金额(人民币)': '1352万元',
#   '中标公司': '中国二十二冶集团有限公司；河北胜康工程设计有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月16日',
#   '项目名称': '隆化县城市景观生态治理和乡村振兴建设PPP项目 --苗木补植及基础设施维修',
#   '中标金额(人民币)': '453万元',
#   '中标公司': '承德泽林林业工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月15日',
#   '项目名称': '生命科学园项目17#楼周边绿化景观道路工程',
#   '中标金额(人民币)': '404万元',
#   '中标公司': '张家口国睿建设发展有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月13日',
#   '项目名称': '定兴县兴达路续建段、鹏程路续建段绿化项目',
#   '中标金额(人民币)': '390万元',
#   '中标公司': '保定睿泰市政工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月13日',
#   '项目名称': '某部看护种植服务项目（二次）',
#   '中标金额(人民币)': '42万元',
#   '中标公司': '河北展创园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '无极县科技街北延、北外环西段、北外环西段与高速连接线交口绿化二期项目一标段',
#   '中标金额(人民币)': '614万元',
#   '中标公司': '河北竣凯建筑装饰工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '无极县科技街北延、北外环西段、北外环西段与高速连接线交口绿化二期项目二标段',
#   '中标金额(人民币)': '128万元',
#   '中标公司': '石家庄至臻至诚路桥工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '双滦客运枢纽站（一期）工程（暂估价部分）绿化苗木采购项目',
#   '中标金额(人民币)': '91万元',
#   '中标公司': '承德县头沟瑞军苗圃',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '城区绿化提质工程-施工',
#   '中标金额(人民币)': '745万元',
#   '中标公司': '河北顶峰土木工程有限公',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目中央第一标段',
#   '中标金额(人民币)': '102万元',
#   '中标公司': '沽源县鸿宇园林绿化有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目中央第二标段',
#   '中标金额(人民币)': '106万元',
#   '中标公司': '河北汪林园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目省级第一标段',
#   '中标金额(人民币)': '80万元',
#   '中标公司': '张家口远锦建筑工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目省级第二标段',
#   '中标金额(人民币)': '90万元',
#   '中标公司': '张家口锦墨建设工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目省级第三标段',
#   '中标金额(人民币)': '114万元',
#   '中标公司': '张家口安泰园林景观工程股份有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目中央第四标段',
#   '中标金额(人民币)': '102万元',
#   '中标公司': '沽源县文东绿化有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目中央第三标段',
#   '中标金额(人民币)': '133万元',
#   '中标公司': '北京绿源基业园林绿化有限责任公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '沽源县2022年中央、省级财政森林抚育补贴项目省级第四标段',
#   '中标金额(人民币)': '148万元',
#   '中标公司': '赤城县绿沐绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月12日',
#   '项目名称': '2023年县城公园绿植及行道树补植工程项目',
#   '中标金额(人民币)': '89万元',
#   '中标公司': '围场满族蒙古族自治县林博苑园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月9日',
#   '项目名称': '2023年菜市村至坝底村道路绿化美化工程项目',
#   '中标金额(人民币)': '461万元',
#   '中标公司': '张家口通泰路美绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月6日',
#   '项目名称': '邯郸市园林局2023年苗木补植项目（第一批）2023年滏东大街、秦皇大街、北仓路、果园路等苗木补植工程',
#   '中标金额(人民币)': '97万元',
#   '中标公司': '邯郸市丛台绿冠花木有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月6日',
#   '项目名称': '邯郸市园林局2023年苗木补植项目（第一批）2023年赵苑、古城广场、丛台西路、北环路及周边苗木补植工程',
#   '中标金额(人民币)': '85万元',
#   '中标公司': '邯郸市博雅花卉有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月6日',
#   '项目名称': '邯郸市园林局2023年苗木补植项目（第一批）2023年赵都路、滏西大街、东环路、世纪大街等苗木补植工程',
#   '中标金额(人民币)': '91万元',
#   '中标公司': '邯郸市丛台绿冠花木有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月6日',
#   '项目名称': '邯郸市园林局2023年苗木补植项目（第一批）2023年南环路、人民东、陵西大街、中华大街、水厂路等苗木补植工程',
#   '中标金额(人民币)': '96万元',
#   '中标公司': '邯郸市自成园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月6日',
#   '项目名称': '邯郸市园林局2023年苗木补植项目（第一批）2023年人民路及周边苗木补植工程',
#   '中标金额(人民币)': '91万元',
#   '中标公司': '邯郸市自成园林绿化工程有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月5日',
#   '项目名称': '深泽县高速连接线高速口至定州界段绿化提升工程施工',
#   '中标金额(人民币)': '648万元',
#   '中标公司': '石家庄市公路桥梁建设集团有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月5日',
#   '项目名称': '沙河市2021年退化林修复工程（二标段）',
#   '中标金额(人民币)': '154万元',
#   '中标公司': '光山县才华苗木专业合作社',
#   '城市': '河北'},
#  {'中标时间': '6月5日',
#   '项目名称': '沙河市2021年退化林修复工程（一标段）',
#   '中标金额(人民币)': '261万元',
#   '中标公司': '沙河市惠泽农林有限公司',
#   '城市': '河北'},
#  {'中标时间': '6月28日',
#   '项目名称': '河北区2023至2024年绿地养护项目',
#   '中标金额(人民币)': '995万元',
#   '中标公司': '天津市津美园林工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月26日',
#   '项目名称': '天津开放大学绿化养护及绿植租摆服务项目',
#   '中标金额(人民币)': '63万元',
#   '中标公司': '天津聚鑫茂园林景观工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月26日',
#   '项目名称': '2023年东丽区重点生态林管护（京津高速公路绿化带提升补植）建设项目',
#   '中标金额(人民币)': '129万元',
#   '中标公司': '天津市生茂园林工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月25日',
#   '项目名称': '天津市红桥区城市管理服务中心对第十四届新领军者年会迎宾保障线沿线园林绿化设施提升项目',
#   '中标金额(人民币)': '58万元',
#   '中标公司': '天津市津淇市政园林工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月19日',
#   '项目名称': '河北区2023年城市公园拆墙透绿提升改造项目',
#   '中标金额(人民币)': '86万元',
#   '中标公司': '天津盛鑫海园林工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月19日',
#   '项目名称': '志成道公租房（盛盈家园）界外绿化工程',
#   '中标金额(人民币)': '146万元',
#   '中标公司': '天津盛鑫海园林工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月15日',
#   '项目名称': '天津市机电工艺技师学院2023-2025年度绿化服务项目',
#   '中标金额(人民币)': '410万元',
#   '中标公司': '天津荣隆达园林绿化工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月14日',
#   '项目名称': '2023年和平区绿化养护服务项目',
#   '中标金额(人民币)': '545万元',
#   '中标公司': '天津市绿化工程有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月9日',
#   '项目名称': '金桥街道军粮城农业园一标段绿化养护项目',
#   '中标金额(人民币)': '220万元',
#   '中标公司': '天津市久益集团有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月6日',
#   '项目名称': '北闸口镇2018年度造林绿化工程2023-2024年度养护管理服务项目',
#   '中标金额(人民币)': '99万元',
#   '中标公司': '天津春浓林业有限公司',
#   '城市': '天津'},
#  {'中标时间': '6月1日',
#   '项目名称': '天津市肿瘤医院空港医院室外绿化养护和楼内花卉租摆服务采购项目',
#   '中标金额(人民币)': '197万元',
#   '中标公司': '天津花之富花卉销售有限公司',
#   '城市': '天津'}]

# %%
collection.insert_many(data)

# %%
collection.delete_many({})

# %%
 df.columns = ['中标时间', '项目名称', '中标金额(万元)', '中标公司', '城市']

# %%
df
# Out:
#       中标时间                                 项目名称   中标金额(万元)             中标公司  \
# 1     中标时间                                 项目名称  中标金额(人民币)             中标公司
# 2    6月30日                         延庆区道路绿化工程二标段      838万元    北京绿佳杰园林工程有限公司
# 3    6月29日                          党校西绿地绿化建设工程      646万元   北京京润园林绿化工程有限公司
# 4    6月29日                德胜街道2023年绿地养护及树木抢排险项目      146万元   北京西城园林绿化有限责任公司
# 5    6月28日    北京城市副中心住房项目（0701街区）D#地块第一标段景观园林工程     2347万元    北京市园林绿化集团有限公司
# ..     ...                                  ...        ...              ...
# 114  6月15日         天津市机电工艺技师学院2023-2025年度绿化服务项目      410万元  天津荣隆达园林绿化工程有限公司
# 115  6月14日                     2023年和平区绿化养护服务项目      545万元      天津市绿化工程有限公司
# 116   6月9日                  金桥街道军粮城农业园一标段绿化养护项目      220万元      天津市久益集团有限公司
# 117   6月6日  北闸口镇2018年度造林绿化工程2023-2024年度养护管理服务项目       99万元       天津春浓林业有限公司
# 118   6月1日       天津市肿瘤医院空港医院室外绿化养护和楼内花卉租摆服务采购项目      197万元    天津花之富花卉销售有限公司
#
#      城市
# 1    北京
# 2    北京
# 3    北京
# 4    北京
# 5    北京
# ..   ..
# 114  天津
# 115  天津
# 116  天津
# 117  天津
# 118  天津
#
# [116 rows x 5 columns]

# %%
df[df['中标金额(万元)'].str.contains('万元')]
# Out:
#       中标时间                                               项目名称 中标金额(万元)  \
# 2    6月30日                                       延庆区道路绿化工程二标段    838万元
# 3    6月29日                                        党校西绿地绿化建设工程    646万元
# 4    6月29日                              德胜街道2023年绿地养护及树木抢排险项目    146万元
# 5    6月28日                  北京城市副中心住房项目（0701街区）D#地块第一标段景观园林工程   2347万元
# 6    6月28日  南区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：黄村公园、街心公园    477万元
# ..     ...                                                ...      ...
# 114  6月15日                       天津市机电工艺技师学院2023-2025年度绿化服务项目    410万元
# 115  6月14日                                   2023年和平区绿化养护服务项目    545万元
# 116   6月9日                                金桥街道军粮城农业园一标段绿化养护项目    220万元
# 117   6月6日                北闸口镇2018年度造林绿化工程2023-2024年度养护管理服务项目     99万元
# 118   6月1日                     天津市肿瘤医院空港医院室外绿化养护和楼内花卉租摆服务采购项目    197万元
#
#                 中标公司  城市
# 2      北京绿佳杰园林工程有限公司  北京
# 3     北京京润园林绿化工程有限公司  北京
# 4     北京西城园林绿化有限责任公司  北京
# 5      北京市园林绿化集团有限公司  北京
# 6     北京日出枫林园林工程有限公司  北京
# ..               ...  ..
# 114  天津荣隆达园林绿化工程有限公司  天津
# 115      天津市绿化工程有限公司  天津
# 116      天津市久益集团有限公司  天津
# 117       天津春浓林业有限公司  天津
# 118    天津花之富花卉销售有限公司  天津
#
# [115 rows x 5 columns]

# %%
cursor = collection.find()

# %%
cursor

# %%
df = pd.DataFrame(list(cursor))

# %%
df
# Out:
#                           _id       中标时间  \
# 0    64bb8fe562b6aede59173dfe 2023-06-30
# 1    64bb8fe562b6aede59173dff 2023-06-29
# 2    64bb8fe562b6aede59173e00 2023-06-29
# 3    64bb8fe562b6aede59173e01 2023-06-28
# 4    64bb8fe562b6aede59173e02 2023-06-28
# ..                        ...        ...
# 910  64bb9352e3040de7bbc779d9 2023-01-08
# 911  64bb9352e3040de7bbc779da 2023-01-05
# 912  64bb9352e3040de7bbc779db 2023-01-05
# 913  64bb9352e3040de7bbc779dc 2023-01-05
# 914  64bb9352e3040de7bbc779dd 2023-01-03
#
#                                                   项目名称  中标金额(万元)  \
# 0                                         延庆区道路绿化工程二标段     838.0
# 1                                          党校西绿地绿化建设工程     646.0
# 2                                德胜街道2023年绿地养护及树木抢排险项目     146.0
# 3                    北京城市副中心住房项目（0701街区）D#地块第一标段景观园林工程    2347.0
# 4    南区公园管理所管辖区内公园绿化养护项目（2023年7月-2024年6月）第一包：黄村公园、街心公园     477.0
# ..                                                 ...       ...
# 910       天津市武清区王庆坨镇人民政府机关 武清区2016年、2017年生态储备林工程养管服务项目      50.0
# 911                        中新天津生态城玉砂道（彩辰路-彩环路）绿化恢复工程施工    1499.0
# 912  中新天津生态城航庆道（渔家路—渔泽路）、航安道（渔家路—渔泽路）、顺明路（航津道—渔家路）、...    2907.0
# 913  天津市西青区辛口镇全域乡村振兴示范项目（一期工程）—西青区大沙沃（窝）村村庄基础设施建设工程...    2720.0
# 914             天津市津南区人民政府海棠街道办事处机关 海棠街环卫作业养护、绿化养护采购项目    9379.0
#
#                  中标公司  城市
# 0       北京绿佳杰园林工程有限公司  北京
# 1      北京京润园林绿化工程有限公司  北京
# 2      北京西城园林绿化有限责任公司  北京
# 3       北京市园林绿化集团有限公司  北京
# 4      北京日出枫林园林工程有限公司  北京
# ..                ...  ..
# 910    天津胜建炜业建筑工程有限公司  天津
# 911      江西景观建设集团有限公司  天津
# 912     中交一航局第一工程有限公司  天津
# 913      浩安生态环境建设有限公司  天津
# 914  天津学苑市政景观建设发展有限公司  天津
#
# [915 rows x 6 columns]

# %%
df.to_csv('zhongbiao.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pyperclip
from pymongo import MongoClient
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from lxml import etree
import re

# %%
def fetch_links(url, scroll_count=10):
    # 初始化Selenium Webdriver
    driver = webdriver.Chrome()

    # 打开网页
    driver.get(url)

    # 模拟滚动页面以加载更多链接
    for _ in range(scroll_count):  # 根据需要调整滚动次数
        body_element = driver.find_element('tag name', 'body')
        body_element.send_keys(Keys.END)
        time.sleep(2)  # 等待页面加载

    # 获取所有相关元素
    elements = driver.find_elements(By.XPATH, "//li[@class='album__list-item js_album_item js_wx_tap_highlight wx_tap_cell']")

    # 从元素中提取并存储data-link属性
    links = []
    for element in elements:
        data_link = [element.get_attribute('data-link'),element.get_attribute('data-title')]
        links.append(data_link)

    # 关闭浏览器
    driver.quit()

    return links

# %%
def get_zb(link):
    response = requests.get(link[0])
    soup = BeautifulSoup(response.text, 'html.parser')

    table = soup.find('table')  # find the table in the webpage

    data = []
    for row in table.find_all('tr'):  # find each row in the table
        cols = row.find_all('td')  # find each column in the row
        cols = [ele.text.strip() for ele in cols]
        data.append(cols)
    
    return data
def process_data(link):
    # Load the data
    df = pd.DataFrame(get_zb(link))

    # Initialize a city variable with a default value
    current_city = '未知'

    # Define a function to determine the city
    def determine_city(row):
        nonlocal current_city
        try:
            if pd.notnull(row[0]) and pd.isnull(row[1]) and pd.isnull(row[2]) and pd.isnull(row[3]):
               current_city = row[0]
        except (KeyError, IndexError):
            pass
        return current_city



    # Apply the function to each row
    df['城市'] = df.apply(determine_city, axis=1)

    # Remove the rows with city names
    try:
        df = df.dropna(subset=[1, 2, 3], how='all')
    except KeyError as e:
        print(f"An error occurred: {e}")

    # Rename the columns
    df.columns = ['中标时间', '项目名称', '中标金额(万元)', '中标公司', '城市']
    df = df[df['中标金额(万元)'].str.contains('万元')]
    # Drop the first row
    df = df.iloc[1:]
    # Convert "中标金额(人民币)" to numeric
    df['中标金额(万元)'] = df['中标金额(万元)'].str.extract(r'(\d+)').astype(float)

    # Add a temporary year to "中标时间" and convert it to datetime
    df['中标时间'] = str(link[1][:4]) +'年' + df['中标时间']
    df['中标时间'] = pd.to_datetime(df['中标时间'], format='%Y年%m月%d日')
    return df
def to_mongo(df):
    client = MongoClient('localhost', 27017)
    db = client['中标公示']
    collection = db['Landscape']
    collection.insert_many(df.to_dict('records'))
def get_date(url):
    response = requests.get(url)
    root = etree.HTML(response.text)
    activity_name = root.xpath("//h1[@id='activity-name']")[0]
    pattern = r"\d+"
    matches = re.findall(pattern, activity_name.text)
    return matches[0]

# %% [markdown]
# # 批量下载

# %%
if __name__ == "__main__":
    url = "https://mp.weixin.qq.com/mp/appmsgalbum?__biz=MjM5MTQwMzA1OQ==&action=getalbum&album_id=1986262221798113281&scene=173&from_msgid=2650716085&from_itemidx=1&count=3&nolastread=1#wechat_redirect"
    scroll_count = 3
    links = fetch_links(url, scroll_count)
    for i in range(20,len(links)):
        zbdf = process_data(links[i])
        to_mongo(zbdf)
        print(f'第{i+1}页数据已存入数据库')
# Out:
# The chromedriver version (116.0.5845.96) detected in PATH at C:\Program Files\Google\Chrome Driver\chromedriver.exe might not be compatible with the detected chrome version (117.0.5938.149); currently, chromedriver 117.0.5938.149 is recommended for chrome 117.*, so it is advised to delete the driver in PATH and retry
# 第21页数据已存入数据库
# 第22页数据已存入数据库
# 第23页数据已存入数据库
# 第24页数据已存入数据库
# 第25页数据已存入数据库
# 第26页数据已存入数据库
# 第27页数据已存入数据库

# %% [markdown]
# # 单页下载

# %%
if __name__ == "__main__":
    url = pyperclip.paste()
    year = get_date(url)
    zbdf = process_data([url,year])
    to_mongo(zbdf)
    print('据已存入数据库')
# Out:
# 据已存入数据库

# %%
url = 'https://mp.weixin.qq.com/s?__biz=MjM5MTQwMzA1OQ==&mid=2650716085&idx=1&sn=9d3d71f54c354bfb373029515c315f2c&chksm=bebc0ae989cb83ff78bfa1ec4f7b87e640cbad2cc0e21ddad95bf7c078295df4c49544568368&scene=178&cur_album_id=1986262221798113281#rd'

# %%
text
# Out:
# '\n            \n2023-9月份京津冀地区园林公司中标公示\n          '

# %%
pattern = r"\d+"

matches = re.findall(pattern, text)

matches[0]
# Out:
# '2023'
